# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import torch
import pandas as pd
from torch.utils.data import DataLoader

from src.resnet50.dataset import ImageDataset
from src.resnet50.model import ResNet, Bottleneck
from src.utils import get_device, get_logger

# %%
def load_model(path_to_checkpoint, device):
    model = ResNet(Bottleneck, [3, 4, 6, 3], dropout_p=0.5)
    checkpoint = torch.load(path_to_checkpoint, map_location=device)
    state = checkpoint["model_state"] if "model_state" in checkpoint else checkpoint
    model.load_state_dict(state)
    model.to(device)
    model.eval()
    return model


def infer_with_resnet(path_to_checkpoint, path_to_dataset, batch_size=128):
    device = "cpu"
    logger = get_logger("inference")

    dataset = ImageDataset(path_to_dataset, max_jets=10000)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    preds, targets = [], []
    with torch.no_grad():
        model = load_model(path_to_checkpoint, device)
        for idx, batch in enumerate(loader):
            logger.info(f"Processing batch {idx}")
            x, y = batch[0], batch[1]
            x = x.to(device)
            out = model(x)
            preds.append(out.detach().cpu())
            targets.append(y.view(-1).detach().cpu())

    preds_all = torch.cat(preds).detach().numpy()
    targets_all = torch.cat(targets).detach().numpy()

    # Handle multi-class outputs: softmax for probabilities
    if preds_all.ndim == 2 and preds_all.shape[1] > 1:
        probs = torch.nn.functional.softmax(torch.tensor(preds_all), dim=1).numpy()
        pred_labels = probs.argmax(axis=1)
        df = pd.DataFrame(probs, columns=[f"prob_{i}" for i in range(probs.shape[1])])
        df["pred"] = pred_labels
        df["target"] = targets_all
    else:
        # Regression or binary classification
        df = pd.DataFrame({
            "pred": preds_all.flatten(),
            "target": targets_all.flatten(),
        })

    return df

# %%
df = infer_with_resnet("../checkpoints/resnet50/best_model.pt", "../data/test-preprocessed.h5")
# Out:
# 2025-09-16 18:00:01 - inference - INFO - Processing batch 0
# 2025-09-16 18:00:01 - inference - INFO - Processing batch 1
# 2025-09-16 18:00:01 - inference - INFO - Processing batch 2
# 2025-09-16 18:00:02 - inference - INFO - Processing batch 3
# 2025-09-16 18:00:02 - inference - INFO - Processing batch 4
# 2025-09-16 18:00:02 - inference - INFO - Processing batch 5
# 2025-09-16 18:00:02 - inference - INFO - Processing batch 6
# 2025-09-16 18:00:03 - inference - INFO - Processing batch 7
# 2025-09-16 18:00:03 - inference - INFO - Processing batch 8
# 2025-09-16 18:00:03 - inference - INFO - Processing batch 9
# 2025-09-16 18:00:03 - inference - INFO - Processing batch 10
# 2025-09-16 18:00:03 - inference - INFO - Processing batch 11
# 2025-09-16 18:00:04 - inference - INFO - Processing batch 12
# 2025-09-16 18:00:04 - inference - INFO - Processing batch 13
# 2025-09-16 18:00:04 - inference - INFO - Processing batch 14
# 2025-09-16 18:00:04 - inference - INFO - Processing batch 15
# 2025-09-16 18:00:04 - inference - INFO - Processing batch 16
# 2025-09-16 18:00:05 - inference - INFO - Processing batch 17
# 2025-09-16 18:00:05 - inference - INFO - Processing batch 18
# 2025-09-16 18:00:05 - inference - INFO - Processing batch 19
# 2025-09-16 18:00:05 - inference - INFO - Processing batch 20
# 2025-09-16 18:00:06 - inference - INFO - Processing batch 21
# 2025-09-16 18:00:06 - inference - INFO - Processing batch 22
# 2025-09-16 18:00:06 - inference - INFO - Processing batch 23
# 2025-09-16 18:00:06 - inference - INFO - Processing batch 24
# 2025-09-16 18:00:06 - inference - INFO - Processing batch 25
# 2025-09-16 18:00:07 - inference - INFO - Processing batch 26
# 2025-09-16 18:00:07 - inference - INFO - Processing batch 27
# 2025-09-16 18:00:07 - inference - INFO - Processing batch 28
# 2025-09-16 18:00:07 - inference - INFO - Processing batch 29
# 2025-09-16 18:00:07 - inference - INFO - Processing batch 30
# 2025-09-16 18:00:08 - inference - INFO - Processing batch 31
# 2025-09-16 18:00:08 - inference - INFO - Processing batch 32
# 2025-09-16 18:00:08 - inference - INFO - Processing batch 33
# 2025-09-16 18:00:08 - inference - INFO - Processing batch 34
# 2025-09-16 18:00:08 - inference - INFO - Processing batch 35
# 2025-09-16 18:00:09 - inference - INFO - Processing batch 36
# 2025-09-16 18:00:09 - inference - INFO - Processing batch 37
# 2025-09-16 18:00:09 - inference - INFO - Processing batch 38
# 2025-09-16 18:00:09 - inference - INFO - Processing batch 39
# 2025-09-16 18:00:09 - inference - INFO - Processing batch 40
# 2025-09-16 18:00:10 - inference - INFO - Processing batch 41
# 2025-09-16 18:00:10 - inference - INFO - Processing batch 42
# 2025-09-16 18:00:10 - inference - INFO - Processing batch 43
# 2025-09-16 18:00:10 - inference - INFO - Processing batch 44
# 2025-09-16 18:00:11 - inference - INFO - Processing batch 45
# 2025-09-16 18:00:11 - inference - INFO - Processing batch 46
# 2025-09-16 18:00:11 - inference - INFO - Processing batch 47
# 2025-09-16 18:00:11 - inference - INFO - Processing batch 48
# 2025-09-16 18:00:11 - inference - INFO - Processing batch 49
# 2025-09-16 18:00:12 - inference - INFO - Processing batch 50
# 2025-09-16 18:00:12 - inference - INFO - Processing batch 51
# 2025-09-16 18:00:12 - inference - INFO - Processing batch 52
# 2025-09-16 18:00:12 - inference - INFO - Processing batch 53
# 2025-09-16 18:00:13 - inference - INFO - Processing batch 54
# 2025-09-16 18:00:13 - inference - INFO - Processing batch 55
# 2025-09-16 18:00:13 - inference - INFO - Processing batch 56
# 2025-09-16 18:00:13 - inference - INFO - Processing batch 57
# 2025-09-16 18:00:13 - inference - INFO - Processing batch 58
# 2025-09-16 18:00:14 - inference - INFO - Processing batch 59
# 2025-09-16 18:00:14 - inference - INFO - Processing batch 60
# 2025-09-16 18:00:14 - inference - INFO - Processing batch 61
# 2025-09-16 18:00:14 - inference - INFO - Processing batch 62
# 2025-09-16 18:00:14 - inference - INFO - Processing batch 63
# 2025-09-16 18:00:15 - inference - INFO - Processing batch 64
# 2025-09-16 18:00:15 - inference - INFO - Processing batch 65
# 2025-09-16 18:00:15 - inference - INFO - Processing batch 66
# 2025-09-16 18:00:15 - inference - INFO - Processing batch 67
# 2025-09-16 18:00:16 - inference - INFO - Processing batch 68
# 2025-09-16 18:00:16 - inference - INFO - Processing batch 69
# 2025-09-16 18:00:16 - inference - INFO - Processing batch 70
# 2025-09-16 18:00:16 - inference - INFO - Processing batch 71
# 2025-09-16 18:00:16 - inference - INFO - Processing batch 72
# 2025-09-16 18:00:17 - inference - INFO - Processing batch 73
# 2025-09-16 18:00:17 - inference - INFO - Processing batch 74
# 2025-09-16 18:00:17 - inference - INFO - Processing batch 75
# 2025-09-16 18:00:17 - inference - INFO - Processing batch 76
# 2025-09-16 18:00:17 - inference - INFO - Processing batch 77
# 2025-09-16 18:00:18 - inference - INFO - Processing batch 78

# %%
df
# Out:
#           pred  target
# 0    -2.330593     0.0
# 1    -3.459027     0.0
# 2    -2.031495     0.0
# 3    -2.542551     0.0
# 4    -1.899415     1.0
# ...        ...     ...
# 9995 -2.571396     0.0
# 9996 -1.797166     1.0
# 9997 -4.244915     0.0
# 9998 -1.976189     1.0
# 9999 -2.027072     0.0
#
# [10000 rows x 2 columns]
